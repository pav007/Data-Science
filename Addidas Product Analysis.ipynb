# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Data Collection
df = pd.read_excel("Adidas US Sales Datasets.xlsx")

# %%
df
# Out:
#       Unnamed: 0   Unnamed: 1             Unnamed: 2           Unnamed: 3  \
# 0            NaN          NaN  Adidas Sales Database                  NaN
# 1            NaN          NaN                    NaN                  NaN
# 2            NaN          NaN                    NaN                  NaN
# 3            NaN     Retailer            Retailer ID         Invoice Date
# 4            NaN  Foot Locker                1185732  2020-01-01 00:00:00
# ...          ...          ...                    ...                  ...
# 9647         NaN  Foot Locker                1185732  2021-01-24 00:00:00
# 9648         NaN  Foot Locker                1185732  2021-01-24 00:00:00
# 9649         NaN  Foot Locker                1185732  2021-02-22 00:00:00
# 9650         NaN  Foot Locker                1185732  2021-02-22 00:00:00
# 9651         NaN  Foot Locker                1185732  2021-02-22 00:00:00
#
#      Unnamed: 4     Unnamed: 5  Unnamed: 6               Unnamed: 7  \
# ...

# %%
#Data Cleaning
df.columns = df.iloc[3]
df = df.iloc[4:,1:].reset_index(drop=True)

# %%
df
# Out:
# 3        Retailer Retailer ID         Invoice Date     Region          State  \
# 0     Foot Locker     1185732  2020-01-01 00:00:00  Northeast       New York
# 1     Foot Locker     1185732  2020-01-02 00:00:00  Northeast       New York
# 2     Foot Locker     1185732  2020-01-03 00:00:00  Northeast       New York
# 3     Foot Locker     1185732  2020-01-04 00:00:00  Northeast       New York
# 4     Foot Locker     1185732  2020-01-05 00:00:00  Northeast       New York
# ...           ...         ...                  ...        ...            ...
# 9643  Foot Locker     1185732  2021-01-24 00:00:00  Northeast  New Hampshire
# 9644  Foot Locker     1185732  2021-01-24 00:00:00  Northeast  New Hampshire
# 9645  Foot Locker     1185732  2021-02-22 00:00:00  Northeast  New Hampshire
# 9646  Foot Locker     1185732  2021-02-22 00:00:00  Northeast  New Hampshire
# 9647  Foot Locker     1185732  2021-02-22 00:00:00  Northeast  New Hampshire
#
# ...

# %%
#col =['Retailer','Retailer ID','Invoice Date','Region','State','City','Product','Price per Unit','Units Sold','Total Sales','Operating Profit','Operating Margin','Sales Method']

# %%
#Data Cleaning
column_names=list(df.columns)

# %%
for i in column_names:
    res=sum(df[i].isnull())
    print("The following column", i,"has",res,"null values")
# Out:
# The following column Retailer has 0 null values
# The following column Retailer ID has 0 null values
# The following column Invoice Date has 0 null values
# The following column Region has 0 null values
# The following column State has 0 null values
# The following column City has 0 null values
# The following column Product has 0 null values
# The following column Price per Unit has 0 null values
# The following column Units Sold has 0 null values
# The following column Total Sales has 0 null values
# The following column Operating Profit has 0 null values
# The following column Operating Margin has 0 null values
# The following column Sales Method has 0 null values

# %%
#EDA of Addidas starts here
#Data Analysis

# %%
df["Retailer"].value_counts()
# Out:
# Foot Locker      2637
# West Gear        2374
# Sports Direct    2032
# Kohl's           1030
# Amazon            949
# Walmart           626
# Name: Retailer, dtype: int64

# %%
pd=df.groupby('Retailer')['Total Sales'].sum()
pd
# Out:
# Retailer
# Amazon            77698912.0
# Foot Locker      220094720.0
# Kohl's           102114753.0
# Sports Direct    182470997.0
# Walmart           74558410.0
# West Gear        242964333.0
# Name: Total Sales, dtype: float64

# %%
#import plotly.express as px
color=sns.color_palette('bright')
plt.pie(df["Retailer"].value_counts().values,labels=df["Retailer"].value_counts().index,colors=color,autopct='%.0f%%')
plt.show()

# %%
#From the above pie diagram we could able to infere that most of the sales were done by West Gear and Least by Southeast

# %%
#Pie chart for better undertsading of the sales made in a region
color=sns.color_palette("bright")
plt.pie(df['Region'].value_counts().values,labels=df['Region'].value_counts().index,colors=color,autopct='%.0f%%')
plt.show()

# %%
#From the above pie diagram we could able to infere that most of the sales were done by Northeast and West Regions
#Least were done by Southeast

# %%
df['Product'].value_counts()
# Out:
# Men's Athletic Footwear      1610
# Men's Street Footwear        1610
# Women's Apparel              1608
# Women's Street Footwear      1608
# Men's Apparel                1606
# Women's Athletic Footwear    1606
# Name: Product, dtype: int64

# %%
color=sns.color_palette('bright')
plt.pie(df['Product'].value_counts().values,labels=df['Product'].value_counts().index,colors=color,autopct='%.0f%%')
plt.show()

# %%
#From the above pie diagram we could able to infere that all of the products are having equal demand.

# %%
color=sns.color_palette('bright')
plt.pie(df['Sales Method'].value_counts().values,labels=df['Sales Method'].value_counts().index,colors=color,autopct='%.0f%%')
plt.show()

# %%
#From the above pie diagram we could able to infere that most of the sales were done in Online Sales method
#Least were sold In--Store

# %%
x=['State','City','Product']
for y in x:
    dig = df[[y,'Operating Margin']].groupby(y).sum()
    dig.plot(kind='bar',figsize=(10,7),title='Total Sales performed by '+y, colormap='rainbow')

# %%
x=['State','City']
for i in x:
    dig=df[[i,'Operating Profit']].groupby(i).sum()
    dig.plot(kind='bar',figsize=(10,7),title='Total Sales performed by '+i, legend=False,colormap='jet')

# %%
#units sold analysis
x=['State','City']
for i in x:
    dig=df[[i,'Units Sold']].groupby(i).sum()
    dig.plot(kind='bar',figsize=(10,7),title='Total Sales performed by '+i, legend=False,colormap='pink')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9648 non-null   object
#  1   Retailer ID       9648 non-null   object
#  2   Invoice Date      9648 non-null   object
#  3   Region            9648 non-null   object
#  4   State             9648 non-null   object
#  5   City              9648 non-null   object
#  6   Product           9648 non-null   object
#  7   Price per Unit    9648 non-null   object
#  8   Units Sold        9648 non-null   object
#  9   Total Sales       9648 non-null   object
#  10  Operating Profit  9648 non-null   object
#  11  Operating Margin  9648 non-null   object
#  12  Sales Method      9648 non-null   object
# dtypes: object(13)
# memory usage: 980.0+ KB

# %%
#convert numerical columns into float data type
num_cols=['Price per Unit','Units Sold','Total Sales','Operating Profit','Operating Margin']
for col in num_cols:
    df[col]=df[col].astype(float)

# %%
#sns.heatmap(corr,xthicklables=corr.colums,ythinklabels=corr.columns)
plot=sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns,cmap='BuPu')

# %%
# From the above we can infere the below facts
# High correlation exists between Total Sales and Operating costs
# Moderate correation exists between Total Sales and Units sold
